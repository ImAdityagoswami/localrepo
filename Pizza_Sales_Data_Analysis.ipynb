# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:/Users/Aditya/Downloads/Pizza/Enhanced_pizza_sell_data_2024-25.xlsx")

# %%
df
# Out:
#      Order ID Restaurant Name         Location          Order Time  \
# 0      ORD001        Domino's     New York, NY 2024-01-05 18:30:00
# 1      ORD002     Papa John's  Los Angeles, CA 2024-02-14 20:00:00
# 2      ORD003  Little Caesars      Chicago, IL 2024-03-21 12:15:00
# 3      ORD004       Pizza Hut        Miami, FL 2024-04-10 19:45:00
# 4      ORD005   Marco's Pizza       Dallas, TX 2024-05-05 13:00:00
# ...       ...             ...              ...                 ...
# 999   ORD1001        Domino's  Albuquerque, NM 2026-07-03 19:00:00
# 1000  ORD1002       Pizza Hut      Atlanta, GA 2026-07-04 20:15:00
# 1001  ORD1003     Papa John's        Omaha, NE 2026-07-05 18:30:00
# 1002  ORD1004  Little Caesars   Louisville, KY 2026-07-06 19:45:00
# 1003  ORD1005   Marco's Pizza    Milwaukee, WI 2026-07-07 20:00:00
#
#            Delivery Time  Delivery Duration (min) Pizza Size    Pizza Type  \
# 0    2024-01-05 18:45:00                       15     Medium           Veg
# ...

# %%
# 1. Dataset ki first 5 rows display karo.
df.head()
# Out:
#   Order ID Restaurant Name         Location          Order Time  \
# 0   ORD001        Domino's     New York, NY 2024-01-05 18:30:00
# 1   ORD002     Papa John's  Los Angeles, CA 2024-02-14 20:00:00
# 2   ORD003  Little Caesars      Chicago, IL 2024-03-21 12:15:00
# 3   ORD004       Pizza Hut        Miami, FL 2024-04-10 19:45:00
# 4   ORD005   Marco's Pizza       Dallas, TX 2024-05-05 13:00:00
#
#         Delivery Time  Delivery Duration (min) Pizza Size    Pizza Type  \
# 0 2024-01-05 18:45:00                       15     Medium           Veg
# 1 2024-02-14 20:25:00                       25      Large       Non-Veg
# 2 2024-03-21 12:35:00                       20      Small         Vegan
# 3 2024-04-10 20:10:00                       25         XL  Cheese Burst
# 4 2024-05-05 13:20:00                       20     Medium       Non-Veg
#
#    Toppings Count  Distance (km)  ... Topping Density Order Month  \
# 0               3            2.5  ...        1.200000     January
# ...

# %%
# 2. Dataset me total rows aur columns count karo.
df.shape
# Out:
# (1004, 25)

# %%
# 3. Dataset ke sabhi column names print karo.
df.columns
# Out:
# Index(['Order ID', 'Restaurant Name', 'Location', 'Order Time',
#        'Delivery Time', 'Delivery Duration (min)', 'Pizza Size', 'Pizza Type',
#        'Toppings Count', 'Distance (km)', 'Traffic Level', 'Payment Method',
#        'Is Peak Hour', 'Is Weekend', 'Delivery Efficiency (min/km)',
#        'Topping Density', 'Order Month', 'Payment Category',
#        'Estimated Duration (min)', 'Delay (min)', 'Is Delayed',
#        'Pizza Complexity', 'Traffic Impact', 'Order Hour',
#        'Restaurant Avg Time'],
#       dtype='str')

# %%
# 4. Dataset ki basic information (`info()`) nikalo.
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Order ID                      1004 non-null   str
#  1   Restaurant Name               1004 non-null   str
#  2   Location                      1004 non-null   str
#  3   Order Time                    1004 non-null   datetime64[us]
#  4   Delivery Time                 1004 non-null   datetime64[us]
#  5   Delivery Duration (min)       1004 non-null   int64
#  6   Pizza Size                    1004 non-null   str
#  7   Pizza Type                    1004 non-null   str
#  8   Toppings Count                1004 non-null   int64
#  9   Distance (km)                 1004 non-null   float64
#  10  Traffic Level                 1004 non-null   str
#  11  Payment Method                1004 non-null   str
#  12  Is Peak Hour                  1004 non-null   bool
# ...

# %%
# 5. Dataset me null values check karo.
df.isnull().sum()
# Out:
# Order ID                        0
# Restaurant Name                 0
# Location                        0
# Order Time                      0
# Delivery Time                   0
# Delivery Duration (min)         0
# Pizza Size                      0
# Pizza Type                      0
# Toppings Count                  0
# Distance (km)                   0
# Traffic Level                   0
# Payment Method                  0
# Is Peak Hour                    0
# Is Weekend                      0
# Delivery Efficiency (min/km)    0
# Topping Density                 0
# Order Month                     0
# Payment Category                0
# Estimated Duration (min)        0
# Delay (min)                     0
# Is Delayed                      0
# Pizza Complexity                0
# Traffic Impact                  0
# Order Hour                      0
# Restaurant Avg Time             0
# dtype: int64

# %%
# 6. Dataset me total orders count karo.
df = df.shape[0]

("Total Orders:", df)
# Out:
# ('Total Orders:', 1004)

# %%
# 7. Sabse zyada Delivery Duration wala order find karo.
df= df[df['Delivery Duration (min)'] == df['Delivery Duration (min)'].max()]

# %%
df
# Out:
#     Order ID Restaurant Name           Location          Order Time  \
# 129   ORD130   Marco's Pizza        Phoenix, AZ 2024-08-05 19:00:00
# 139   ORD140   Marco's Pizza     Fort Worth, TX 2024-08-15 19:00:00
# 149   ORD150   Marco's Pizza         Boston, MA 2024-08-25 19:00:00
# 270   ORD271   Marco's Pizza          Miami, FL 2024-09-14 19:00:00
# 309   ORD311   Marco's Pizza        Phoenix, AZ 2024-08-30 19:00:00
# 319   ORD321   Marco's Pizza     Fort Worth, TX 2024-09-09 19:00:00
# 329   ORD331   Marco's Pizza         Boston, MA 2024-09-19 19:00:00
# 334   ORD336   Marco's Pizza        Phoenix, AZ 2024-09-24 19:00:00
# 339   ORD341   Marco's Pizza        Phoenix, AZ 2024-09-29 19:00:00
# 349   ORD351   Marco's Pizza     Fort Worth, TX 2024-10-09 19:00:00
# 359   ORD361   Marco's Pizza         Boston, MA 2024-10-19 19:00:00
# 365   ORD367   Marco's Pizza        Phoenix, AZ 2024-10-25 19:00:00
# 375   ORD377   Marco's Pizza     Fort Worth, TX 2024-11-04 19:00:00
# ...

# %%
# 7.
df["Delivery Duration (min)"].max()
# Out:
# np.int64(50)

# %%
# 8. Top 5 longest delivery orders display karo.
df.sort_values(by='Delivery Duration (min)',ascending=False).head(5)
# Out:
#     Order ID Restaurant Name        Location          Order Time  \
# 129   ORD130   Marco's Pizza     Phoenix, AZ 2024-08-05 19:00:00
# 139   ORD140   Marco's Pizza  Fort Worth, TX 2024-08-15 19:00:00
# 149   ORD150   Marco's Pizza      Boston, MA 2024-08-25 19:00:00
# 270   ORD271   Marco's Pizza       Miami, FL 2024-09-14 19:00:00
# 309   ORD311   Marco's Pizza     Phoenix, AZ 2024-08-30 19:00:00
#
#           Delivery Time  Delivery Duration (min) Pizza Size Pizza Type  \
# 129 2024-08-05 19:50:00                       50      Large    Non-Veg
# 139 2024-08-15 19:50:00                       50      Large    Non-Veg
# 149 2024-08-25 19:50:00                       50      Large    Non-Veg
# 270 2024-09-14 19:50:00                       50      Large    Non-Veg
# 309 2024-08-30 19:50:00                       50      Large    Non-Veg
#
#      Toppings Count  Distance (km)  ... Topping Density Order Month  \
# 129               4           10.0  ...             0.4      August
# ...

# %%
# 9. Dataset me kitne unique Pizza Types hain, count karo.
df['Pizza Type'].unique()
# Out:
# <StringArray>
# [          'Veg',       'Non-Veg',         'Vegan',  'Cheese Burst',
#    'Gluten-Free', 'Stuffed Crust',    'Thin Crust',     'Deep Dish',
#   'Thai Chicken',      'Sicilian',   'BBQ Chicken',     'Margarita']
# Length: 12, dtype: str

# %%
# 10. Average Delivery Duration calculate karo.
df['Delivery Duration (min)'].mean()
# Out:
# np.float64(29.49203187250996)

# %%
# 11. Har Pizza Type ka total orders count karo.
df['Pizza Type'].value_counts()
# Out:
# Pizza Type
# Non-Veg          216
# Veg              202
# Cheese Burst     188
# Vegan            132
# Sicilian          64
# BBQ Chicken       54
# Margarita         54
# Gluten-Free       41
# Thai Chicken      24
# Stuffed Crust     21
# Deep Dish          6
# Thin Crust         2
# Name: count, dtype: int64

# %%
# 12. Sabse zyada order hone wala Pizza Type find karo.
df['Pizza Type'].value_counts().idxmax()
# Out:
# 'Non-Veg'

# %%
# 13. Medium size pizzas ke total orders count karo.
medium = df[df['Pizza Size']== 'Medium'].shape[0]
print('Total_Medium_size pizza',medium)
# Out:
# Total_Medium_size pizza 429

# %%
# 14. Large size pizzas ke total orders count karo
Large = df[df['Pizza Size']=='Large'].shape[0]
print('Total_Large_size pizza',Large)
# Out:
# Total_Large_size pizza 240

# %%
# 15. Sabse kam Delivery Duration wala order find karo.
df[df['Delivery Duration (min)']==df['Delivery Duration (min)'].min()]
# Out:
#   Order ID Restaurant Name      Location          Order Time  \
# 0   ORD001        Domino's  New York, NY 2024-01-05 18:30:00
#
#         Delivery Time  Delivery Duration (min) Pizza Size Pizza Type  \
# 0 2024-01-05 18:45:00                       15     Medium        Veg
#
#    Toppings Count  Distance (km)  ... Topping Density Order Month  \
# 0               3            2.5  ...             1.2     January
#
#    Payment Category  Estimated Duration (min)  Delay (min)  Is Delayed  \
# 0            Online                       6.0          9.0       False
#
#   Pizza Complexity Traffic Impact  Order Hour  Restaurant Avg Time
# 0                6              2          18            30.259434
#
# [1 rows x 25 columns]

# %%
df['Delivery Duration (min)'].min()
# Out:
# np.int64(15)

# %%
# 16. Dataset ko Delivery Duration ke according ascending order me sort karo.
df.sort_values(by='Delivery Duration (min)',ascending=True)
# Out:
#     Order ID Restaurant Name           Location          Order Time  \
# 0     ORD001        Domino's       New York, NY 2024-01-05 18:30:00
# 27    ORD028  Little Caesars         Boston, MA 2024-01-28 18:30:00
# 22    ORD023  Little Caesars        Houston, TX 2024-01-23 19:30:00
# 29    ORD030   Marco's Pizza          Miami, FL 2024-01-30 13:15:00
# 10    ORD011        Domino's  San Francisco, CA 2024-01-11 17:30:00
# ..       ...             ...                ...                 ...
# 385   ORD387   Marco's Pizza         Boston, MA 2024-11-14 19:00:00
# 391   ORD393   Marco's Pizza        Phoenix, AZ 2024-11-20 19:00:00
# 365   ORD367   Marco's Pizza        Phoenix, AZ 2024-10-25 19:00:00
# 375   ORD377   Marco's Pizza     Fort Worth, TX 2024-11-04 19:00:00
# 349   ORD351   Marco's Pizza     Fort Worth, TX 2024-10-09 19:00:00
#
#           Delivery Time  Delivery Duration (min) Pizza Size Pizza Type  \
# 0   2024-01-05 18:45:00                       15     Medium        Veg
# ...

# %%
# 17. Sirf Veg pizzas ka data filter karo.
df[df['Pizza Type'] == 'Veg']
# Out:
#      Order ID Restaurant Name           Location          Order Time  \
# 0      ORD001        Domino's       New York, NY 2024-01-05 18:30:00
# 6      ORD007     Papa John's    Los Angeles, CA 2024-01-07 20:15:00
# 10     ORD011        Domino's  San Francisco, CA 2024-01-11 17:30:00
# 15     ORD016        Domino's         Denver, CO 2024-01-16 19:45:00
# 20     ORD021        Domino's          Miami, FL 2024-01-21 18:45:00
# ...       ...             ...                ...                 ...
# 980    ORD982       Pizza Hut        Atlanta, GA 2026-06-14 20:15:00
# 985    ORD987       Pizza Hut        Atlanta, GA 2026-06-19 20:30:00
# 990    ORD992       Pizza Hut        Atlanta, GA 2026-06-24 20:15:00
# 995    ORD997       Pizza Hut        Atlanta, GA 2026-06-29 20:30:00
# 1000  ORD1002       Pizza Hut        Atlanta, GA 2026-07-04 20:15:00
#
#            Delivery Time  Delivery Duration (min) Pizza Size Pizza Type  \
# ...

# %%
# 18. Total Distance (km) ka sum calculate karo.
df['Distance (km)'].sum()
# Out:
# np.float64(4965.4)

# %%
# 19. Kisi ek specific Pizza Type ka complete data display karo.
df[df['Pizza Type'] == 'Veg']
# Out:
#      Order ID Restaurant Name           Location          Order Time  \
# 0      ORD001        Domino's       New York, NY 2024-01-05 18:30:00
# 6      ORD007     Papa John's    Los Angeles, CA 2024-01-07 20:15:00
# 10     ORD011        Domino's  San Francisco, CA 2024-01-11 17:30:00
# 15     ORD016        Domino's         Denver, CO 2024-01-16 19:45:00
# 20     ORD021        Domino's          Miami, FL 2024-01-21 18:45:00
# ...       ...             ...                ...                 ...
# 980    ORD982       Pizza Hut        Atlanta, GA 2026-06-14 20:15:00
# 985    ORD987       Pizza Hut        Atlanta, GA 2026-06-19 20:30:00
# 990    ORD992       Pizza Hut        Atlanta, GA 2026-06-24 20:15:00
# 995    ORD997       Pizza Hut        Atlanta, GA 2026-06-29 20:30:00
# 1000  ORD1002       Pizza Hut        Atlanta, GA 2026-07-04 20:15:00
#
#            Delivery Time  Delivery Duration (min) Pizza Size Pizza Type  \
# ...

# %%
# 20. Top 3 most ordered pizzas find karo.
df['Pizza Type'].value_counts().head(3)
# Out:
# Pizza Type
# Non-Veg         216
# Veg             202
# Cheese Burst    188
# Name: count, dtype: int64
